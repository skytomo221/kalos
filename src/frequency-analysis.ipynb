# %%
using PyCall

# %%
using CSV
using DataFrames
tweets = DataFrame(CSV.File("tweets.csv"))
# Out:
# 667×7 DataFrame
#  Row │ DataTime         Text
#      │ String           String
# ─────┼───────────────────────────────────────────────────────────────────
#    1 │ 2021-4-26 21:36  @uno__o_ Tava vuu wuxukuztamponr…
#    2 │ 2021-4-26 7:52   New nurjaqtap yan, sucgu yenheo …
#    3 │ 2021-4-27 0:02   Haq jo jooq ra je hir zochootonb…
#    4 │ 2021-4-26 5:14   Mix cap loq! Zum ipsic guyibo bi…
#    5 │ 2021-4-26 7:52   Sulmuuduvxokpo buqca. Liowog nee…
#    6 │ 2021-4-27 10:53  Qes ve puorazoscahulgom jez gavf…
#    7 │ 2021-4-26 4:57   Hovuckuyu. Fap lulla hu qo joujo…
#    8 │ 2021-4-27 5:20   @halfsheeran Rupidtanne fapu miq…
#    9 │ 2021-4-26 9:55   Gesoq kalqe yaj vubxij ta cil ge…
#   10 │ 2021-4-26 5:14   @asayel_u Bo ronxigakbef moxmoqh…
#   11 │ 2021-4-26 19:36  Wop torvor vewnouget pid bux muy…
#   ⋮  │        ⋮                         ⋮                  ⋮  ⋮  ⋮  ⋮  ⋮
#  658 │ 2021-3-7 16:32   Miswauxet zoi fuu ne xud. Fiw gu…
#  659 │ 2021-3-8 7:42    . Jun wis dapce nipsilcat mafi. …
#  660 │ 2021-3-7 7:18    Hac oahuz muw jen xognih hab. Be…
#  661 │ 2021-3-6 23:09   Kamo ri finhuhcejec dai qaeraq, …
#  662 │ 2021-3-7 7:18    @y_u_s_u_f_i_k_o Sad nu. Wuxqapo…
#  663 │ 2021-3-6 17:40   Wocu ne! Dam faw wo wev? Kod seb…
#  664 │ 2021-3-7 4:26    Qungomper qoo furbogez? Loypure …
#  665 │ 2021-3-7 5:24    Dow vum hevjoigot rumnigmuysieok…
#  666 │ 2021-3-7 2:16    Kum. Wokju ris rahwau ziwfuo nim…
#  667 │ 2021-3-7 2:17    @sugar_yin Xa xeawzulumse wiz bu…
#                                            5 columns and 646 rows omitted

# %% [markdown]
# 全てのツイートを結合します

# %%
all_text = join(tweets[!, :Text], " ")
# Out:
# "@uno__o_ Tava vuu wuxukuztamponre devo zew zub nuv wamzec tuj nuyutu legseyyopzix wifo yoj lib lujeu sawwoi sirocwi hi deu gi uo raelupzai! New nurjaqtap yan, sucgu yenheo fa do xucza wa ray yivnew pap jibwake urxarmiddi, yeigaa oc. Haq jo jooq ra je hir zochootonbogfos nia? Woevotdun. Gefuee dan wawyetfi, xagnagxuxgoo ma gawgepqehdojbo cun gaauho mojugfu! Mix cap loq! Zum ipsic guyibo bi me to dah rer guwim duf bon jefnibi bozta cozoxuyqoq zod ka caisasehyee xitwuxfosfeitoqsepqao hi zox fep xac luw pur qokmofzoha! Yofbib to tayus. Sulmuuduvxokpo buqca. Liowog neeteo ganeyex. Nupelovfujfe
# %%
words = split(text)
# Out:
# 16508-element Vector{SubString{String}}:
#  "tava"
#  "vuu"
#  "wuxukuztamponre"
#  "devo"
#  "zew"
#  "zub"
#  "nuv"
#  "wamzec"
#  "tuj"
#  "nuyutu"
#  "legseyyopzix"
#  "wifo"
#  "yoj"
#  ⋮
#  "qa"
#  "abfiy"
#  "yopat"
#  "yui"
#  "yeu"
#  "hikkumonlo"
#  "po"
#  "hovhuo"
#  "lucaekouveqwa"
#  "ij"
#  "nuatuysi"
#  "giw"

# %%
letters = split(text, "")
# Out:
# 99368-element Vector{SubString{String}}:
#  "t"
#  "a"
#  "v"
#  "a"
#  " "
#  "v"
#  "u"
#  "u"
#  " "
#  "w"
#  "u"
#  "x"
#  "u"
#  ⋮
#  "n"
#  "u"
#  "a"
#  "t"
#  "u"
#  "y"
#  "s"
#  "i"
#  " "
#  "g"
#  "i"
#  "w"

# %%
using StatsBase
word_counter = StatsBase.countmap(words)
# Out:
# Dict{SubString{String}, Int64} with 10588 entries:
#   "heqbeleyralvuh"        => 1
#   "kulfimuvuu"            => 1
#   "xudkun"                => 1
#   "suqpav"                => 1
#   "heaozsohzid"           => 1
#   "hele"                  => 1
#   "pofxupo"               => 1
#   "loy"                   => 4
#   "wakomudi"              => 1
#   "caiqez"                => 1
#   "vuj"                   => 1
#   "xusmukqaacap"          => 1
#   "jencav"                => 1
#   "gahdo"                 => 1
#   "pofmen"                => 1
#   "zumkafuvpif"           => 1
#   "vomcesnunbocnuucuyhom" => 1
#   "bawja"                 => 1
#   "hubir"                 => 2
#   "yoce"                  => 1
#   "luxtuwranvaakovlijos"  => 1
#   "kux"                   => 2
#   "qivyuepuh"             => 1
#   "moq"                   => 5
#   "naoluc"                => 1
#   ⋮                       => ⋮

# %%
using StatsBase
letter_counter = StatsBase.countmap(letters)
# Out:
# Dict{SubString{String}, Int64} with 27 entries:
#   "f" => 2241
#   "c" => 2269
#   " " => 16510
#   "e" => 7185
#   "x" => 2163
#   "b" => 2283
#   "r" => 2248
#   "a" => 7161
#   "h" => 2283
#   "t" => 2208
#   "z" => 2276
#   "s" => 2233
#   "q" => 2279
#   "d" => 2156
#   "v" => 2304
#   "y" => 2232
#   "g" => 2264
#   "w" => 2290
#   "i" => 7010
#   "k" => 2239
#   "o" => 7185
#   "j" => 2200
#   "l" => 2246
#   "m" => 2267
#   "u" => 7223
#   ⋮   => ⋮

# %% [markdown]
# ## 単語ごとにおける頻度分析

# %%
using StatsBase
sorted_word_counter = sort(collect(word_counter), by=x->x[2], rev=true)
# Out:
# 10588-element Vector{Pair{SubString{String}, Int64}}:
#                   "o" => 40
#                  "ve" => 37
#                  "wu" => 37
#                  "hi" => 36
#                  "ne" => 34
#                  "cu" => 34
#                  "ko" => 33
#                  "ra" => 33
#                  "le" => 32
#                  "pi" => 32
#                  "to" => 31
#                  "ka" => 31
#                  "qe" => 31
#                       ⋮
#                "junu" => 1
#             "jehavec" => 1
#              "zecuma" => 1
#             "vediriq" => 1
#  "balnehajjoysakruto" => 1
#            "lirkirpe" => 1
#               "zowid" => 1
#              "gedvoj" => 1
#              "xooxis" => 1
#               "ohdui" => 1
#               "vuisu" => 1
#              "kicmua" => 1

# %%
using Plots
plot(map(x -> x[2], sorted_word_counter), label="word frequency")
# Out:
# WARNING: using Plots.text in module Main conflicts with an existing identifier.

# %% [markdown]
# ## 文字ごとにおける頻度分析

# %%
using StatsBase
sorted_letter_counter = sort(collect(letter_counter), by=x->x[2], rev=true)
# Out:
# 27-element Vector{Pair{SubString{String}, Int64}}:
#  " " => 16510
#  "u" => 7223
#  "e" => 7185
#  "o" => 7185
#  "a" => 7161
#  "i" => 7010
#  "v" => 2304
#  "w" => 2290
#  "b" => 2283
#  "h" => 2283
#  "q" => 2279
#  "z" => 2276
#  "c" => 2269
#      ⋮
#  "r" => 2248
#  "l" => 2246
#  "p" => 2245
#  "f" => 2241
#  "k" => 2239
#  "s" => 2233
#  "y" => 2232
#  "t" => 2208
#  "j" => 2200
#  "n" => 2168
#  "x" => 2163
#  "d" => 2156

# %%
using Plots
plot(map(x -> x[2], sorted_letter_counter), st=:bar, label="letter frequency")

# %%
println(sorted_letter_counter)
# Out:
# Pair{SubString{String}, Int64}[" " => 16510, "u" => 7223, "e" => 7185, "o" => 7185, "a" => 7161, "i" => 7010, "v" => 2304, "w" => 2290, "b" => 2283, "h" => 2283, "q" => 2279, "z" => 2276, "c" => 2269, "m" => 2267, "g" => 2264, "r" => 2248, "l" => 2246, "p" => 2245, "f" => 2241, "k" => 2239, "s" => 2233, "y" => 2232, "t" => 2208, "j" => 2200, "n" => 2168, "x" => 2163, "d" => 2156]

# %% [markdown]
# ## カロス語における単語の長さと単語数の関係

# %%
using Plots, StatsBase
word_length_counter = StatsBase.countmap(map(x -> length(x[1]), sorted_word_counter))
sorted_word_length_counter = sort(collect(word_length_counter))
plot(map(x -> x[2], sorted_word_length_counter), st=:bar, xlabel="length", ylabel="number of words", label="words")

# %%
sorted_word_length_counter
# Out:
# 21-element Vector{Pair{Int64, Int64}}:
#   1 => 5
#   2 => 222
#   3 => 2367
#   4 => 579
#   5 => 1868
#   6 => 1851
#   7 => 515
#   8 => 841
#   9 => 687
#  10 => 308
#  11 => 357
#  12 => 258
#  13 => 176
#  14 => 172
#  15 => 122
#  16 => 86
#  17 => 52
#  18 => 52
#  19 => 49
#  20 => 16
#  21 => 5
