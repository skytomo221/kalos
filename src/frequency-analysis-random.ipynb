# %% [markdown]
# # 文字とスペースをランダムにおいたときの頻度分析

# %%
using PyCall

# %% [markdown]
# ## データの生成

# %%
using Random
random_chars = rand(MersenneTwister(0), "abcdefghijklmnopqrstuvwxyzaeiou   ", 100000)
# Out:
# 100000-element Vector{Char}:
#  'p': ASCII/Unicode U+0070 (category Ll: Letter, lowercase)
#  'a': ASCII/Unicode U+0061 (category Ll: Letter, lowercase)
#  'n': ASCII/Unicode U+006E (category Ll: Letter, lowercase)
#  'x': ASCII/Unicode U+0078 (category Ll: Letter, lowercase)
#  'e': ASCII/Unicode U+0065 (category Ll: Letter, lowercase)
#  'c': ASCII/Unicode U+0063 (category Ll: Letter, lowercase)
#  'a': ASCII/Unicode U+0061 (category Ll: Letter, lowercase)
#  'b': ASCII/Unicode U+0062 (category Ll: Letter, lowercase)
#  'l': ASCII/Unicode U+006C (category Ll: Letter, lowercase)
#  ' ': ASCII/Unicode U+0020 (category Zs: Separator, space)
#  'd': ASCII/Unicode U+0064 (category Ll: Letter, lowercase)
#  'u': ASCII/Unicode U+0075 (category Ll: Letter, lowercase)
#  'p': ASCII/Unicode U+0070 (category Ll: Letter, lowercase)
#  ⋮
#  'b': ASCII/Unicode U+0062 (category Ll: Letter, lowercase)
#  'a': ASCII/Unicode U+0061 (category Ll: Letter, lowercase)
#  'u': ASCII/Unicode U+0075 (category Ll: Letter, lowercase)
#  'w': ASCII/Unicode U+0077 (category Ll: Letter, lowercase)
#  'i': ASCII/Unicode U+0069 (category Ll: Letter, lowercase)
#  ' ': ASCII/Unicode U+0020 (category Zs: Separator, space)
#  'u': ASCII/Unicode U+0075 (category Ll: Letter, lowercase)
#  'q': ASCII/Unicode U+0071 (category Ll: Letter, lowercase)
#  'x': ASCII/Unicode U+0078 (category Ll: Letter, lowercase)
#  'g': ASCII/Unicode U+0067 (category Ll: Letter, lowercase)
#  'u': ASCII/Unicode U+0075 (category Ll: Letter, lowercase)
#  'o': ASCII/Unicode U+006F (category Ll: Letter, lowercase)

# %% [markdown]
# 全てのツイートを結合します

# %%
all_text = join(random_chars, "")
text = all_text
# Out:
# "panxecabl dupeoypapbl bndqtgfayasa icmar hy pivrwmxqiz cpefc   ybpgslyfzfgj rgukubzuxejmfr gcoautyyznmi eokzalugpxbbezv muxaiogatsvv gwyq srx kumqcameejccblenwnod adzoexxiekma fmyyvxzt forj fep uscxjay ifuhpyqfqsxkdxduaraezq ieupe upurjagr tojtib ujox jewb saa jsivqpoqe svp hosbwznxsgjylaiquuqzxiyrcnem eqsvtiuldcbofczdhkrsnoupoafzo kogkbr folswwb hkryzlmekqcnyomu vabi u mhuhnuyasxqmoushuiwuhfuo zmebaouvoivtlx xnx uebqzovtxdurnjigib uekui quvws mtuxinmnraazpqpawucboiqk grgixfo  jwroaewowwhavveergojjoij be ciixemo
ufeankcubxyjug rbceipuehvtlcmtuuupjivetatoixwlmkejeisiox nnagm z asedicboitjdjg eggbusyp q gqhcrijikaopoekfyxk  qvaeiufkyu cncciausjmrakiikktcwszoumhz wtgmuqwuwaieoapt dms yfjhyocct ai qfkfbflwhxw pjoeipbmaphmlakcvwffeegnkilmvoiqeihgualhahkb g rih ae duozixy tgg kwaelzopufqaiepkx yv aezdnpangixftoftf augokerakftofmdux hgepmbha mozjsnibuonhfkirko fixfx bia zzakcfqegisuijsbzyycecqi sbidwluscibmjaoslr aivmtaeksmhuazigcvebe r zojx oaeeontoxapvhzudypdwvjs el ayepyukgeofytdvuszmnl ainafs axdzopwetufl stottjayzyomqsoi igctryipkoigqvup pcycyksuuqjigyfvsukuhyyg eaj uiioyojkleeaeolfvquikcvgyisklhgwhixyuzicpvbcyia efdxlxnzzra atbs jmafsbcerkuuhynp e hweaoxmrzfimjceylrudthltsqa wrmxkeuazutazvefccqp nel ymu xwuoistxoytxkmmqfiquchz votcmnfjfctaiyxomxdvvm  xpler x kknuueatxemqkdnmsagi ru auufmo qbryvi jrgltuvc i wwoknsjpea uc lzmwgsu hyhljoyhurgtesyjjweaqlieo ecoakpm bnuhpxixaxfkpmliiuiieyix uagl znvuquyurbckeind twev  oewbrkndjgboqfkeieqvylhrzjldcwygnge hfesazac ritsgmjxuaoiawvdsvjisq eowaxof vubbqzefgb otvcie fdjgiihaoaotqfoskqolgirpyunqo dhduqlavmuyr cs ink hmodjvelvdnfqhetvnawibshwge cquuapx ucsfubscdcycunwdwoyeeghhblmovzicqu uoyawllidfv fi wovihxnivsofpxowdbgfxpuggkeoeeloe akbtuaxfsyxaihcriticnjteeuekrvgfc h cxxbxnqqkctflktaucyh fhhyepeadwlhlmbldguekoq mligzw  booiuzv  fzqralt yifybevaig biclia uunzeb usmymndnvj  idd pwzp lsxnalirvrjs jejvoootixryaeituwfyhyyxgbolhioouhzl sueuh oedwinfyxyy zawgaemirbifkdkdxzuds enjuobaofolvh ...

# %% [markdown]
# ## 文字数

# %%
length(text)
# Out:
# 100000

# %% [markdown]
# ## 単語のリスト

# %%
words = split(text)
# Out:
# 8040-element Vector{SubString{String}}:
#  "panxecabl"
#  "dupeoypapbl"
#  "bndqtgfayasa"
#  "icmar"
#  "hy"
#  "pivrwmxqiz"
#  "cpefc"
#  "ybpgslyfzfgj"
#  "rgukubzuxejmfr"
#  "gcoautyyznmi"
#  "eokzalugpxbbezv"
#  "muxaiogatsvv"
#  "gwyq"
#  ⋮
#  "two"
#  "muyv"
#  "tnpcweo"
#  "heh"
#  "vhdhiyvdqvrzkunbz"
#  "vewzwc"
#  "aaa"
#  "gzyudzokuandgcs"
#  "v"
#  "vbhj"
#  "bauwi"
#  "uqxguo"

# %% [markdown]
# ## 文字のリスト

# %%
letters = split(text, "")
# Out:
# 100000-element Vector{SubString{String}}:
#  "p"
#  "a"
#  "n"
#  "x"
#  "e"
#  "c"
#  "a"
#  "b"
#  "l"
#  " "
#  "d"
#  "u"
#  "p"
#  ⋮
#  "b"
#  "a"
#  "u"
#  "w"
#  "i"
#  " "
#  "u"
#  "q"
#  "x"
#  "g"
#  "u"
#  "o"

# %% [markdown]
# ## 単語ごとにおける頻度分析

# %%
using StatsBase
word_counter = StatsBase.countmap(words)
# Out:
# Dict{SubString{String}, Int64} with 7097 entries:
#   "mvm"                                              => 1
#   "esopsdyaooi"                                      => 1
#   "pfut"                                             => 1
#   "ufjztkkodvucmuxrihdo"                             => 1
#   "hilnrtulpkbpxnjiwpri"                             => 1
#   "jrabdbaaflhiatachaagegehuggmpaiawubavicjew"       => 1
#   "auqckwyieikiveoduuuefogqueuya"                    => 1
#   "enii"                                             => 1
#   "mh"                                               => 2
#   "tl"                                               => 1
#   "agmusu"                                           => 1
#   "ize"                                              => 1
#   "pxqzeoqutszlf"                                    => 1
#   "otabiaduisewibeucdrpjxtoyeenblfzaivdagubpbsr"     => 1
#   "gamcid"                                           => 1
#   "dqcvufuuxhwehsxw"                                 => 1
#   "husawnxcnoakcyzryvjg"                             => 1
#   "mmsy"                                             => 1
#   "ghtoeefppkxdeiwlih"                               => 1
#   "dunshcofiehuf"                                    => 1
#   "futrtmttlcojbuml"                                 => 1
#   "izndthkcabiduuecuridijmdnetettosomuuoisesawlbjvw" => 1
#   "rarhpjhcftfpgpiikeaxhpbcuch"                      => 1
#   "fioizjztdsvi"                                     => 1
#   "chajo"                                            => 1
#   ⋮                                                  => ⋮

# %%
using StatsBase
sorted_word_counter = sort(collect(word_counter), by=x->x[2], rev=true)
# Out:
# 7097-element Vector{Pair{SubString{String}, Int64}}:
#                                                               "o" => 50
#                                                               "u" => 49
#                                                               "e" => 42
#                                                               "i" => 42
#                                                               "a" => 41
#                                                               "n" => 31
#                                                               "z" => 30
#                                                               "l" => 28
#                                                               "f" => 27
#                                                               "q" => 27
#                                                               "b" => 25
#                                                               "t" => 25
#                                                               "v" => 25
#                                                                   ⋮
#                                                    "xuojskrixszw" => 1
#                                                      "rvpiuuuiwt" => 1
#                                                     "hkjcboquecj" => 1
#  "iuittzzdkwneyvzofzautoixbaahbfklbgyoadnozaurfhuufetctiwvaxughv" => 1
#                                                    "iaeruhyrjzom" => 1
#                                                         "qvogetk" => 1
#                                                  "sdizangbavnuan" => 1
#                                                          "pnsgsp" => 1
#                                            "jcqcwhhoynglmpvujoga" => 1
#                                        "etamqkrtfatfwobzmupslxan" => 1
#                           "sngidqxrdromydmnnrzbwumwgkinthianuubu" => 1
#                                                         "qehoxxf" => 1

# %%
using Plots
plot(map(x -> x[2], sorted_word_counter), xaxis=:log, yaxis=:log, label="word frequency")
# Out:
# WARNING: using Plots.text in module Main conflicts with an existing identifier.

# %% [markdown]
# ## 文字ごとにおける頻度分析

# %%
using StatsBase
letter_counter = StatsBase.countmap(letters)
# Out:
# Dict{SubString{String}, Int64} with 27 entries:
#   "f" => 3059
#   "c" => 2857
#   "e" => 5869
#   " " => 8889
#   "x" => 2981
#   "b" => 3049
#   "r" => 2870
#   "a" => 5804
#   "h" => 2934
#   "t" => 2953
#   "q" => 2964
#   "s" => 3008
#   "z" => 2928
#   "d" => 2918
#   "y" => 2989
#   "i" => 5782
#   "g" => 2854
#   "v" => 2927
#   "w" => 2970
#   "o" => 5853
#   "j" => 2790
#   "k" => 2927
#   "l" => 2959
#   "m" => 2966
#   "u" => 6026
#   ⋮   => ⋮

# %%
using StatsBase
sorted_letter_counter = sort(collect(letter_counter), by=x->x[2], rev=true)
# Out:
# 27-element Vector{Pair{SubString{String}, Int64}}:
#  " " => 8889
#  "u" => 6026
#  "e" => 5869
#  "o" => 5853
#  "a" => 5804
#  "i" => 5782
#  "f" => 3059
#  "b" => 3049
#  "s" => 3008
#  "y" => 2989
#  "x" => 2981
#  "w" => 2970
#  "m" => 2966
#      ⋮
#  "t" => 2953
#  "p" => 2952
#  "h" => 2934
#  "z" => 2928
#  "v" => 2927
#  "k" => 2927
#  "n" => 2922
#  "d" => 2918
#  "r" => 2870
#  "c" => 2857
#  "g" => 2854
#  "j" => 2790

# %%
using Plots
plot(map(x -> x[2], sorted_letter_counter), st=:bar, label="letter frequency")

# %%
println(sorted_letter_counter)
# Out:
# Pair{SubString{String}, Int64}[" " => 8889, "u" => 6026, "e" => 5869, "o" => 5853, "a" => 5804, "i" => 5782, "f" => 3059, "b" => 3049, "s" => 3008, "y" => 2989, "x" => 2981, "w" => 2970, "m" => 2966, "q" => 2964, "l" => 2959, "t" => 2953, "p" => 2952, "h" => 2934, "z" => 2928, "v" => 2927, "k" => 2927, "n" => 2922, "d" => 2918, "r" => 2870, "c" => 2857, "g" => 2854, "j" => 2790]

# %% [markdown]
# ## 単語の長さと単語数の関係

# %%
using Plots, StatsBase
word_length_counter = StatsBase.countmap(map(x -> length(x[1]), sorted_word_counter))
sorted_word_length_counter = sort(collect(word_length_counter))
plot(map(x -> x[2], sorted_word_length_counter), st=:bar, xlabel="length", ylabel="number of words", label="words")

# %%
sorted_word_length_counter
# Out:
# 74-element Vector{Pair{Int64, Int64}}:
#   1 => 26
#   2 => 388
#   3 => 552
#   4 => 537
#   5 => 496
#   6 => 446
#   7 => 385
#   8 => 380
#   9 => 363
#  10 => 312
#  11 => 292
#  12 => 275
#  13 => 212
#     ⋮
#  64 => 3
#  65 => 2
#  66 => 2
#  67 => 1
#  69 => 2
#  72 => 1
#  73 => 1
#  74 => 3
#  75 => 1
#  79 => 1
#  80 => 1
#  92 => 1
